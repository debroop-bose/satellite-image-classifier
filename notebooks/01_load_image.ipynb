# %%
import sys
print(sys.executable)
# Out:
# /opt/homebrew/opt/python@3.11/bin/python3.11

# %%
import sys
import subprocess

# Make sure pip exists in this environment
subprocess.check_call([sys.executable, "-m", "ensurepip", "--upgrade"])

# Install pillow into the SAME Python Jupyter is using
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "pillow"])
# Out:
# Looking in links: /var/folders/9d/21dvbbwd297cnjs1zr6bkdzm0000gn/T/tmpy87at1tq
# ...
# 0

# %%
import sys
import subprocess

# Make sure pip exists
subprocess.check_call([sys.executable, "-m", "ensurepip", "--upgrade"])

# Upgrade pip first (recommended)
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])

# Install numpy and matplotlib
subprocess.check_call([sys.executable, "-m", "pip", "install", "numpy"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "matplotlib"])
# Out:
# Looking in links: /var/folders/9d/21dvbbwd297cnjs1zr6bkdzm0000gn/T/tmpjm_w0s9x
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 10.5 MB/s  0:00:00 eta 0:00:01
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 8.8 MB/s  0:00:00 eta 0:00:01m
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 9.8 MB/s  0:00:00 eta 0:00:01
# ...
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# ...
# 0

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.asarray(Image.open("/Users/ray/Projects/satellite-image-classifier/images/landsat-eight.jpg"))
print(repr(img))
# Out:
# array([[[ 11,  12,  30],
#         [ 11,  12,  30],
#         [ 11,  12,  30],
#         ...,
#         [147, 153, 119],
#         [157, 165, 128],
#         [136, 144, 107]],
#
#        [[ 11,  12,  30],
#         [ 11,  12,  30],
#         [ 11,  12,  30],
#         ...,
#         [162, 168, 132],
#         [184, 190, 154],
#         [172, 180, 141]],
#
#        [[ 11,  12,  30],
#         [ 11,  12,  30],
#         [ 11,  12,  30],
#         ...,
#         [116, 120,  83],
#         [131, 135,  98],
#         [120, 127,  86]],
#
#        ...,
#
#        [[ 19,  70,  61],
#         [ 19,  70,  61],
#         [ 19,  70,  61],
#         ...,
#         [140, 123,  95],
#         [140, 123,  95],
#         [138, 121,  93]],
#
#        [[ 19,  70,  61],
#         [ 19,  70,  61],
#         [ 19,  70,  61],
#         ...,
#         [141, 124,  96],
#         [141, 124,  96],
#         [140, 123,  95]],
#
#        [[ 19,  70,  61],
#         [ 19,  70,  61],
#         [ 19,  70,  61],
# ...

# %%
imgplot = plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1079.5), np.float64(-0.5))

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
img[100, 100]
# Out:
# array([11, 12, 30], dtype=uint8)

# %%
num_images=len(img)

data = []
for i in range(num_images):
    
    avgR = np.mean(img[:, :, 2])
    avgG = np.mean(img[:, :, 1])
    avgB = np.mean(img[:, :, 0])
    
print(avgR)
print(avgG)
print(avgB)
# Out:
# 74.46807629243827
# 85.50739969135803
# 67.15460792824074
